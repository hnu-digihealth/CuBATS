# %%
import os
from valis import registration

###Set OpenSlide Path
OPENSLIDE_PATH = r"c:\Users\mlnot\anaconda3\envs\DoctorThesis\Lib\site-packages\openslide\openslide-win64-20231011\openslide-win64-20231011\bin"

if hasattr(os, "add_dll_directory"):
    # Windows
    with os.add_dll_directory(OPENSLIDE_PATH):
        import openslide
else:
    import openslide
# Out:
# c:\Users\mlnot\anaconda3\envs\DoctorThesis\Lib\site-packages\numba\core\decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# c:\Users\mlnot\anaconda3\envs\DoctorThesis\Lib\site-packages\valis\affine_optimizer.py:311: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @nba.jit()
# ...

# %%
slide_src_dir = r"c:/Users/mlnot/Desktop/Slides/N_2014_000862_MRXS/"
results_dst_dir = (
    r"C:\Users\mlnot\Desktop\Slides\VALIS Out\slide_registration_N_2014_000862"
)
registered_slide_dest_dir = r"C:\Users\mlnot\Desktop\Slides\VALIS Out\slide_registration_N_2014_000862/registered_slides"

# %%
# Create a Valis object and use it to register the slides in slide_src_dir
registrar = registration.Valis(slide_src_dir, results_dst_dir)
rigid_registrar, non_rigid_registrar, error_df = registrar.register()
registrar.register_micro(max_non_rigid_registartion_dim_px=2000)
# Out:
# JVM has been initialized. Be sure to call registration.kill_jvm() or slide_io.kill_jvm() at the end of your script.
# c:\Users\mlnot\anaconda3\envs\DoctorThesis\Lib\site-packages\valis\valtils.py:75: UserWarning: found 3 matches for N_2014_000862_PDPN: c:/Users/mlnot/Desktop/Slides/N_2014_000862_MRXS/N_2014_000862_PDPN.mrxs, c:/Users/mlnot/Desktop/Slides/N_2014_000862_MRXS/N_2014_000862_PDPN_NZ1, c:/Users/mlnot/Desktop/Slides/N_2014_000862_MRXS/N_2014_000862_PDPN_NZ1.mrxs
#   warnings.warn(warning_msg, warning_type)
# ==== Converting images
# 100%|██████████| 7/7 [00:01<00:00,  4.12it/s]
# ==== Processing images
# 100%|██████████| 7/7 [00:06<00:00,  1.00it/s]
# ==== Normalizing images
# 100%|██████████| 7/7 [00:00<00:00, 21.24it/s]
# ==== Rigid registraration
# 100%|██████████| 7/7 [00:00<00:00,  7.88it/s]
# ======== Detecting features
# 100%|██████████| 7/7 [00:02<00:00,  2.89it/s]
# ======== Matching images
# 100%|██████████| 21/21 [00:01<00:00, 14.51it/s]
# ...

# %%
slideobj = registrar.get_slide("N_2014_000862_ROR2.mrxs")
slideobj.warp_and_save_slide("lastout.ome.tiff")
# Out:
# saving lastout.ome.tiff (67467 x 148648 and 3 channels)
#
# [====================================================================================================] 100.0% in 16.303 minutes
# Complete

# %%
registrar.warp_and_save_slides(registered_slide_dest_dir, crop="overlap")
registration.kill_jvm()
